# %%
import pandas as pd

# %%
df = pd.read_csv("../Submission/cities.csv")
df.head()
# Out:
#         City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     albany   42.6001   -73.9662     60.53      83.0        34.0        2.53
# 1    mataura  -46.1927   168.8643     48.47      99.0       100.0        1.48
# 2    rikitea  -23.1203  -134.9692     70.47      72.0        44.0       19.57
# 3  namatanai   -3.6667   152.4333     82.92      70.0        29.0        3.47
# 4    labuhan   -6.8844   112.2051     87.80      56.0        14.0        6.51
#
#   Country          Date
# 0      US  1.627796e+09
# 1      NZ  1.627796e+09
# 2      PF  1.627796e+09
# 3      PG  1.627796e+09
# 4      ID  1.627796e+09

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>albany</td>
#       <td>42.6001</td>
#       <td>-73.9662</td>
#       <td>60.53</td>
#       <td>83.0</td>
#       <td>34.0</td>
#       <td>2.53</td>
#       <td>US</td>
#       <td>1.627796e+09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mataura</td>
#       <td>-46.1927</td>
#       <td>168.8643</td>
#       <td>48.47</td>
#       <td>99.0</td>
#       <td>100.0</td>
#       <td>1.48</td>
#       <td>NZ</td>
#       <td>1.627796e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>rikitea</td>
#       <td>-23.1203</td>
#       <td>-134.9692</td>
# ...

# %%
df.to_html("data_table.html")
